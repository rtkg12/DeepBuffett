# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv", header = None)

# %%
df.head()
# Out:
#    Unnamed: 0 Company        Date     Revenue  Revenue Growth  \
# 0           0    ANTE  2018-12-31  11036000.0        0.065662
# 1           1    ANTE  2018-09-30  10356000.0       -0.108625
# 2           2    ANTE  2018-06-30  11618000.0       -0.325437
# 3           3    ANTE  2018-03-31  17223000.0       -0.738228
# 4           4    ANTE  2017-12-31  65794000.0        0.000000
#
#    Cost of Revenue  Gross Profit  R&D Expenses  SG&A Expense  \
# 0              NaN    -2138000.0           NaN           NaN
# 1              NaN    -2138000.0           NaN           NaN
# 2              NaN    -1904000.0           NaN           NaN
# 3              NaN    -1904000.0           NaN           NaN
# 4              NaN    -7356500.0           NaN           NaN
#
#    Operating Expenses  ...  Free Cash Flow growth  Receivables growth  \
# 0          18346500.0  ...                    NaN             -0.2636
# 1          18346500.0  ...                    NaN             -0.2636
# ...
