# %%
import torch
import os
import pandas as pd
import numpy as np
import time
import random
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
RANDOM_SEED = 123
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
class StockDataset(Dataset):
    def __init__(self, csv_path):
        df = pd.read_csv(csv_path)
        self.y = df['Label'].to_numpy().astype(int)
        self.features = df.drop(["Company", "Date", "Target", "Label"], axis=1).to_numpy().astype('float32')

    def __getitem__(self, index):
        features = self.features[index]
        label = self.y[index]
        
        return features, label

    def __len__(self):
        return self.y.shape[0]

# %%
BATCH_SIZE = 128

# %%
train_dataset = StockDataset(csv_path='./My Data/train.csv')


train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=4)


valid_dataset = StockDataset(csv_path='./My Data/val.csv')

valid_loader = DataLoader(dataset=valid_dataset,
                          batch_size=BATCH_SIZE,
                          shuffle=False,
                          num_workers=4)

test_dataset = StockDataset(csv_path='./My Data/test.csv')

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=BATCH_SIZE,
                         shuffle=False,
                         num_workers=4)

# %%
torch.manual_seed(0)

num_epochs = 2
for epoch in range(num_epochs):

    for batch_idx, (x, y) in enumerate(train_loader):
        
        print('Epoch:', epoch+1, end='')
        print(' | Batch index:', batch_idx, end='')
        print(' | Batch size:', y.size()[0])
        
        x = x.to(DEVICE)
        y = y.to(DEVICE)
        print('break minibatch for-loop')
        break
# Out:
# Epoch: 1 | Batch index: 0 | Batch size: 128
# break minibatch for-loop
# Epoch: 2 | Batch index: 0 | Batch size: 128
# break minibatch for-loop

# %%
class SoftmaxRegression(torch.nn.Module):

    def __init__(self, num_features, num_classes):
        super(SoftmaxRegression, self).__init__()
        self.linear = torch.nn.Linear(num_features, num_classes)
        
        self.linear.weight.detach().normal_(0.0, 0.1)
        self.linear.bias.detach().zero_()
        
    def forward(self, x):
        logits = self.linear(x)
        probas = F.softmax(logits, dim=1)
        return logits, probas

# %%
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# %%
model = SoftmaxRegression(num_features=143, num_classes=3)
model = model.to(DEVICE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-a7a242b77bf0> in <module>
# ----> 1 model = SoftmaxRegression(num_features=143, num_classes=3)
#       2 model = model.to(DEVICE)
#
# <ipython-input-114-c92cf9bfd7ea> in __init__(self, num_features, num_classes)
#       4         super(SoftmaxRegression, self).__init__()
#       5         self.linear = torch.nn.Linear(num_features, num_classes)
# ----> 6         torch.nn.init.xavier_uniform_(conv1.weight)
#       7
#       8 #         self.linear.weight.detach().zero_()
#
# NameError: name 'conv1' is not defined

# %%
num_features = 143
num_classes = 3

# %%
learning_rate = 0.1

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum = 0.9)
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)

# %%
NUM_EPOCHS = 50

# %%
def compute_accuracy(model, data_loader):
    correct_pred, num_examples = 0, 0
    
    for features, targets in data_loader:
        features = features.view(-1, num_features).to(DEVICE)
        targets = targets.to(DEVICE)
        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
        
    return correct_pred.float() / num_examples * 100

start_time = time.time()
epoch_costs = []
for epoch in range(NUM_EPOCHS):
    avg_cost = 0.
    for batch_idx, (features, targets) in enumerate(train_loader):
        
        features = features.view(-1, num_features).to(DEVICE)
        targets = targets.to(DEVICE)
            
        ### FORWARD AND BACK PROP
        logits, probas = model(features)
        
        # note that the PyTorch implementation of
        # CrossEntropyLoss works with logits, not
        # probabilities
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        cost.backward()
        avg_cost += cost
        avg_cost
        
        ### UPDATE MODEL PARAMETERS
        optimizer.step()
        
        ### LOGGING
        if not batch_idx % 200:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Cost: %.4f' 
                   %(epoch+1, NUM_EPOCHS, batch_idx, 
                     len(train_dataset)//BATCH_SIZE, cost))
            
    with torch.set_grad_enabled(False):
        avg_cost = avg_cost/len(train_dataset)
        epoch_costs.append(avg_cost)
        print('Epoch: %03d/%03d training accuracy: %.2f%%' % (
              epoch+1, NUM_EPOCHS, 
              compute_accuracy(model, train_loader)))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/050 | Batch 000/490 | Cost: 1.0986
# Epoch: 001/050 | Batch 200/490 | Cost: 1.0927
# Epoch: 001/050 | Batch 400/490 | Cost: 1.2282
# Epoch: 001/050 training accuracy: 44.90%
# Time elapsed: 0.02 min
# Epoch: 002/050 | Batch 000/490 | Cost: 1.0846
# Epoch: 002/050 | Batch 200/490 | Cost: 1.0882
# Epoch: 002/050 | Batch 400/490 | Cost: 1.0794
# Epoch: 002/050 training accuracy: 44.86%
# Time elapsed: 0.03 min
# Epoch: 003/050 | Batch 000/490 | Cost: 1.0757
# Epoch: 003/050 | Batch 200/490 | Cost: 1.0843
# Epoch: 003/050 | Batch 400/490 | Cost: 1.0428
# Epoch: 003/050 training accuracy: 44.93%
# Time elapsed: 0.05 min
# Epoch: 004/050 | Batch 000/490 | Cost: 1.0971
# Epoch: 004/050 | Batch 200/490 | Cost: 1.0864
# Epoch: 004/050 | Batch 400/490 | Cost: 1.0676
# Epoch: 004/050 training accuracy: 44.97%
# Time elapsed: 0.07 min
# Epoch: 005/050 | Batch 000/490 | Cost: 1.0845
# Epoch: 005/050 | Batch 200/490 | Cost: 1.0772
# Epoch: 005/050 | Batch 400/490 | Cost: 1.0641
# Epoch: 005/050 training accuracy: 44.99%
# Time elapsed: 0.08 min
# Epoch: 006/050 | Batch 000/490 | Cost: 1.0664
# Epoch: 006/050 | Batch 200/490 | Cost: 1.0664
# Epoch: 006/050 | Batch 400/490 | Cost: 1.0901
# Epoch: 006/050 training accuracy: 45.01%
# Time elapsed: 0.10 min
# Epoch: 007/050 | Batch 000/490 | Cost: 1.0535
# Epoch: 007/050 | Batch 200/490 | Cost: 1.1206
# Epoch: 007/050 | Batch 400/490 | Cost: 1.0475
# Epoch: 007/050 training accuracy: 45.00%
# Time elapsed: 0.12 min
# Epoch: 008/050 | Batch 000/490 | Cost: 1.0532
# Epoch: 008/050 | Batch 200/490 | Cost: 1.1049
# Epoch: 008/050 | Batch 400/490 | Cost: 1.1040
# Epoch: 008/050 training accuracy: 45.01%
# Time elapsed: 0.13 min
# Epoch: 009/050 | Batch 000/490 | Cost: 1.0530
# Epoch: 009/050 | Batch 200/490 | Cost: 1.0684
# Epoch: 009/050 | Batch 400/490 | Cost: 1.0591
# Epoch: 009/050 training accuracy: 45.00%
# Time elapsed: 0.15 min
# Epoch: 010/050 | Batch 000/490 | Cost: 1.0390
# Epoch: 010/050 | Batch 200/490 | Cost: 1.0673
# Epoch: 010/050 | Batch 400/490 | Cost: 1.0576
# Epoch: 010/050 training accuracy: 44.95%
# Time elapsed: 0.17 min
# Epoch: 011/050 | Batch 000/490 | Cost: 1.0760
# Epoch: 011/050 | Batch 200/490 | Cost: 1.0687
# Epoch: 011/050 | Batch 400/490 | Cost: 1.0716
# Epoch: 011/050 training accuracy: 44.95%
# Time elapsed: 0.18 min
# Epoch: 012/050 | Batch 000/490 | Cost: 1.0568
# Epoch: 012/050 | Batch 200/490 | Cost: 1.0744
# Epoch: 012/050 | Batch 400/490 | Cost: 1.0427
# Epoch: 012/050 training accuracy: 44.95%
# Time elapsed: 0.20 min
# Epoch: 013/050 | Batch 000/490 | Cost: 1.0418
# Epoch: 013/050 | Batch 200/490 | Cost: 1.0607
# Epoch: 013/050 | Batch 400/490 | Cost: 1.0776
# Epoch: 013/050 training accuracy: 44.96%
# Time elapsed: 0.22 min
# Epoch: 014/050 | Batch 000/490 | Cost: 1.0683
# Epoch: 014/050 | Batch 200/490 | Cost: 1.0527
# Epoch: 014/050 | Batch 400/490 | Cost: 1.0922
# Epoch: 014/050 training accuracy: 44.96%
# Time elapsed: 0.24 min
# Epoch: 015/050 | Batch 000/490 | Cost: 1.0870
# Epoch: 015/050 | Batch 200/490 | Cost: 1.0127
# Epoch: 015/050 | Batch 400/490 | Cost: 1.0354
# Epoch: 015/050 training accuracy: 44.96%
# Time elapsed: 0.25 min
# Epoch: 016/050 | Batch 000/490 | Cost: 1.0562
# Epoch: 016/050 | Batch 200/490 | Cost: 1.0872
# Epoch: 016/050 | Batch 400/490 | Cost: 1.0520
# Epoch: 016/050 training accuracy: 45.01%
# Time elapsed: 0.27 min
# Epoch: 017/050 | Batch 000/490 | Cost: 1.0316
# Epoch: 017/050 | Batch 200/490 | Cost: 1.0995
# Epoch: 017/050 | Batch 400/490 | Cost: 1.0241
# Epoch: 017/050 training accuracy: 44.97%
# Time elapsed: 0.29 min
# Epoch: 018/050 | Batch 000/490 | Cost: 1.0491
# Epoch: 018/050 | Batch 200/490 | Cost: 1.0912
# Epoch: 018/050 | Batch 400/490 | Cost: 1.0949
# Epoch: 018/050 training accuracy: 44.98%
# Time elapsed: 0.30 min
# Epoch: 019/050 | Batch 000/490 | Cost: 1.0948
# Epoch: 019/050 | Batch 200/490 | Cost: 1.0601
# Epoch: 019/050 | Batch 400/490 | Cost: 1.0684
# Epoch: 019/050 training accuracy: 44.99%
# Time elapsed: 0.32 min
# Epoch: 020/050 | Batch 000/490 | Cost: 1.0475
# Epoch: 020/050 | Batch 200/490 | Cost: 1.0555
# Epoch: 020/050 | Batch 400/490 | Cost: 1.0756
# Epoch: 020/050 training accuracy: 44.99%
# Time elapsed: 0.33 min
# Epoch: 021/050 | Batch 000/490 | Cost: 1.0740
# Epoch: 021/050 | Batch 200/490 | Cost: 1.0360
# Epoch: 021/050 | Batch 400/490 | Cost: 1.0846
# Epoch: 021/050 training accuracy: 44.96%
# Time elapsed: 0.35 min
# Epoch: 022/050 | Batch 000/490 | Cost: 1.1028
# Epoch: 022/050 | Batch 200/490 | Cost: 1.0780
# Epoch: 022/050 | Batch 400/490 | Cost: 1.0498
# Epoch: 022/050 training accuracy: 45.00%
# Time elapsed: 0.37 min
# Epoch: 023/050 | Batch 000/490 | Cost: 1.0629
# Epoch: 023/050 | Batch 200/490 | Cost: 1.0711
# Epoch: 023/050 | Batch 400/490 | Cost: 1.0936
# Epoch: 023/050 training accuracy: 45.01%
# Time elapsed: 0.38 min
# Epoch: 024/050 | Batch 000/490 | Cost: 1.0635
# Epoch: 024/050 | Batch 200/490 | Cost: 1.0434
# Epoch: 024/050 | Batch 400/490 | Cost: 1.0473
# Epoch: 024/050 training accuracy: 45.00%
# Time elapsed: 0.40 min
# Epoch: 025/050 | Batch 000/490 | Cost: 1.0699
# Epoch: 025/050 | Batch 200/490 | Cost: 1.0476
# Epoch: 025/050 | Batch 400/490 | Cost: 1.0815
# Epoch: 025/050 training accuracy: 45.03%
# Time elapsed: 0.42 min
# Epoch: 026/050 | Batch 000/490 | Cost: 1.0585
# Epoch: 026/050 | Batch 200/490 | Cost: 1.0815
# Epoch: 026/050 | Batch 400/490 | Cost: 1.0370
# Epoch: 026/050 training accuracy: 44.99%
# Time elapsed: 0.43 min
# Epoch: 027/050 | Batch 000/490 | Cost: 1.0195
# Epoch: 027/050 | Batch 200/490 | Cost: 1.0290
# Epoch: 027/050 | Batch 400/490 | Cost: 1.0879
# Epoch: 027/050 training accuracy: 45.04%
# Time elapsed: 0.45 min
# Epoch: 028/050 | Batch 000/490 | Cost: 1.0584
# Epoch: 028/050 | Batch 200/490 | Cost: 1.0388
# Epoch: 028/050 | Batch 400/490 | Cost: 1.0812
# Epoch: 028/050 training accuracy: 45.03%
# Time elapsed: 0.47 min
# Epoch: 029/050 | Batch 000/490 | Cost: 1.0188
# Epoch: 029/050 | Batch 200/490 | Cost: 1.0295
# Epoch: 029/050 | Batch 400/490 | Cost: 1.0705
# Epoch: 029/050 training accuracy: 44.99%
# Time elapsed: 0.48 min
# Epoch: 030/050 | Batch 000/490 | Cost: 1.0750
# Epoch: 030/050 | Batch 200/490 | Cost: 1.0692
# Epoch: 030/050 | Batch 400/490 | Cost: 1.0737
# Epoch: 030/050 training accuracy: 45.01%
# Time elapsed: 0.50 min
# Epoch: 031/050 | Batch 000/490 | Cost: 1.0605
# Epoch: 031/050 | Batch 200/490 | Cost: 1.0774
# Epoch: 031/050 | Batch 400/490 | Cost: 1.0423
# Epoch: 031/050 training accuracy: 44.99%
# Time elapsed: 0.51 min
# Epoch: 032/050 | Batch 000/490 | Cost: 1.0356
# Epoch: 032/050 | Batch 200/490 | Cost: 1.0445
# Epoch: 032/050 | Batch 400/490 | Cost: 1.0784
# Epoch: 032/050 training accuracy: 45.00%
# Time elapsed: 0.53 min
# Epoch: 033/050 | Batch 000/490 | Cost: 1.0571
# Epoch: 033/050 | Batch 200/490 | Cost: 1.0612
# Epoch: 033/050 | Batch 400/490 | Cost: 1.0940
# Epoch: 033/050 training accuracy: 44.98%
# Time elapsed: 0.55 min
# Epoch: 034/050 | Batch 000/490 | Cost: 1.0822
# Epoch: 034/050 | Batch 200/490 | Cost: 1.0639
# Epoch: 034/050 | Batch 400/490 | Cost: 1.0719
# Epoch: 034/050 training accuracy: 44.98%
# Time elapsed: 0.56 min
# Epoch: 035/050 | Batch 000/490 | Cost: 1.0663
# Epoch: 035/050 | Batch 200/490 | Cost: 1.0508
# Epoch: 035/050 | Batch 400/490 | Cost: 1.0712
# Epoch: 035/050 training accuracy: 45.00%
# Time elapsed: 0.58 min
# Epoch: 036/050 | Batch 000/490 | Cost: 1.0742
# Epoch: 036/050 | Batch 200/490 | Cost: 1.0240
# Epoch: 036/050 | Batch 400/490 | Cost: 1.0753
# Epoch: 036/050 training accuracy: 45.03%
# Time elapsed: 0.59 min
# Epoch: 037/050 | Batch 000/490 | Cost: 1.0543
# Epoch: 037/050 | Batch 200/490 | Cost: 1.0739
# Epoch: 037/050 | Batch 400/490 | Cost: 1.0666
# Epoch: 037/050 training accuracy: 45.01%
# Time elapsed: 0.61 min
# Epoch: 038/050 | Batch 000/490 | Cost: 1.0582
# Epoch: 038/050 | Batch 200/490 | Cost: 1.0831
# Epoch: 038/050 | Batch 400/490 | Cost: 1.0752
# Epoch: 038/050 training accuracy: 45.03%
# Time elapsed: 0.63 min
# Epoch: 039/050 | Batch 000/490 | Cost: 1.0501
# Epoch: 039/050 | Batch 200/490 | Cost: 1.0555
# Epoch: 039/050 | Batch 400/490 | Cost: 1.0448
# Epoch: 039/050 training accuracy: 45.02%
# Time elapsed: 0.65 min
# Epoch: 040/050 | Batch 000/490 | Cost: 1.0641
# Epoch: 040/050 | Batch 200/490 | Cost: 1.0780
# Epoch: 040/050 | Batch 400/490 | Cost: 1.0958
# Epoch: 040/050 training accuracy: 45.01%
# Time elapsed: 0.66 min
# Epoch: 041/050 | Batch 000/490 | Cost: 1.0651
# Epoch: 041/050 | Batch 200/490 | Cost: 1.0315
# Epoch: 041/050 | Batch 400/490 | Cost: 1.0697
# Epoch: 041/050 training accuracy: 45.02%
# Time elapsed: 0.68 min
# Epoch: 042/050 | Batch 000/490 | Cost: 1.0300
# Epoch: 042/050 | Batch 200/490 | Cost: 1.0265
# Epoch: 042/050 | Batch 400/490 | Cost: 1.0842
# Epoch: 042/050 training accuracy: 45.02%
# Time elapsed: 0.70 min
# Epoch: 043/050 | Batch 000/490 | Cost: 1.0795
# Epoch: 043/050 | Batch 200/490 | Cost: 1.0594
# Epoch: 043/050 | Batch 400/490 | Cost: 1.0694
# Epoch: 043/050 training accuracy: 45.05%
# Time elapsed: 0.71 min
# Epoch: 044/050 | Batch 000/490 | Cost: 1.0636
# Epoch: 044/050 | Batch 200/490 | Cost: 1.0551
# Epoch: 044/050 | Batch 400/490 | Cost: 1.0545
# Epoch: 044/050 training accuracy: 45.06%
# Time elapsed: 0.73 min
# Epoch: 045/050 | Batch 000/490 | Cost: 1.0613
# Epoch: 045/050 | Batch 200/490 | Cost: 1.0884
# Epoch: 045/050 | Batch 400/490 | Cost: 1.0734
# Epoch: 045/050 training accuracy: 45.05%
# Time elapsed: 0.75 min
# Epoch: 046/050 | Batch 000/490 | Cost: 1.0541
# Epoch: 046/050 | Batch 200/490 | Cost: 1.0709
# Epoch: 046/050 | Batch 400/490 | Cost: 1.0335
# Epoch: 046/050 training accuracy: 45.02%
# Time elapsed: 0.76 min
# Epoch: 047/050 | Batch 000/490 | Cost: 1.0671
# Epoch: 047/050 | Batch 200/490 | Cost: 1.0390
# Epoch: 047/050 | Batch 400/490 | Cost: 1.0869
# Epoch: 047/050 training accuracy: 45.04%
# Time elapsed: 0.78 min
# Epoch: 048/050 | Batch 000/490 | Cost: 1.0922
# Epoch: 048/050 | Batch 200/490 | Cost: 1.0955
# Epoch: 048/050 | Batch 400/490 | Cost: 1.1112
# Epoch: 048/050 training accuracy: 45.00%
# Time elapsed: 0.80 min
# Epoch: 049/050 | Batch 000/490 | Cost: 1.0739
# Epoch: 049/050 | Batch 200/490 | Cost: 1.1065
# Epoch: 049/050 | Batch 400/490 | Cost: 1.0725
# Epoch: 049/050 training accuracy: 45.04%
# Time elapsed: 0.81 min
# Epoch: 050/050 | Batch 000/490 | Cost: 1.0463
# Epoch: 050/050 | Batch 200/490 | Cost: 1.1005
# Epoch: 050/050 | Batch 400/490 | Cost: 1.0622
# Epoch: 050/050 training accuracy: 45.02%
# Time elapsed: 0.83 min
